# %% [markdown]
# <a href="https://colab.research.google.com/github/PhamAnhKiet20146220/AI-T7-tiet_1234/blob/main/AI_ST7_W8_Crabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url ="/content/crabs.csv"
data = pd.read_csv(url)
data.head()
# Out:
#   speies sex  index  fontallip  rearwidth  length  width  depth
# 0      B   M      1        8.1        6.7    16.1   19.0    7.0
# 1      B   M      2        8.8        7.7    18.1   20.8    7.4
# 2      B   M      3        9.2        7.8    19.0   22.4    7.7
# 3      B   M      4        9.6        7.9    20.1   23.1    8.2
# 4      B   M      5        9.8        8.0    20.3   23.0    8.2

# %%
dataframe = pd.read_csv(url)
dataframe['speies'].replace("B", "0")
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    O
# 196    O
# 197    O
# 198    O
# 199    O
# Name: speies, Length: 200, dtype: object

# %%
dataframe['speies'].replace(["B", "O"], ["0", "1"])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: speies, Length: 200, dtype: object

# %%
dataframe['sex'].replace(["M", "F"], ["0", "1"])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: sex, Length: 200, dtype: object

# %%
from sklearn import datasets
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
x=data.loc[:,['index','speies','fontallip','rearwidth','length','width','depth']]
y=data['sex']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
sc=StandardScaler()
sc.fit(x_train)
x_train_Std=sc.transform(x_train)
x_test_Std=sc.transform(x_test)

# %%
print(x_train,x_train_Std)
# Out:
#      index  speies  fontallip  rearwidth  length  width  depth
# 102      3       0       10.7        8.6    20.7   22.7    9.2
# 0        1       0        8.1        6.7    16.1   19.0    7.0
# 190     41       0       20.3       16.0    39.4   44.1   18.0
# 176     27       0       18.3       15.7    35.1   40.5   16.1
# 139     40       0       19.4       14.4    39.8   44.3   17.9
# ..     ...     ...        ...        ...     ...    ...    ...
# 172     23       0       17.5       14.7    33.3   37.6   14.6
# 3        4       0        9.6        7.9    20.1   23.1    8.2
# 195     46       0       21.4       18.0    41.2   46.2   18.7
# 130     31       0       17.9       12.9    36.9   40.9   16.5
# 153      4       0       12.6       11.5    25.0   28.1   11.5
#
# [140 rows x 7 columns] [[-1.58794872e+00  0.00000000e+00 -1.47896864e+00 -1.66208225e+00
#   -1.67656520e+00 -1.80975109e+00 -1.48781947e+00]
#  [-1.72650455e+00  0.00000000e+00 -2.25985721e+00 -2.41333778e+00
# ...

# %%
model=Perceptron(max_iter=10000, eta0=0.05,random_state=0)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(y_pred)
print(y_test)
print('Độ chính xác của mô hình chưa Scale:',accuracy_score(y_test,y_pred))
# Out:
# ['M' 'F' 'M' 'M' 'M' 'M' 'F' 'M' 'M' 'M' 'M' 'F' 'M' 'M' 'M' 'M' 'F' 'F'
#  'M' 'F' 'M' 'M' 'M' 'F' 'M' 'M' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'M'
#  'M' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'M' 'F'
#  'M' 'F' 'F' 'F' 'F' 'M']
# 179    F
# 57     F
# 7      M
# 133    M
# 46     M
# 37     M
# 196    F
# 137    M
# 171    F
# 34     M
# 101    M
# 53     F
# 132    M
# 8      M
# 115    M
# 125    M
# 180    F
# 64     F
# 5      M
# 155    F
# 103    M
# 117    M
# 149    M
# 87     F
# 31     M
# 144    M
# 69     F
# 129    M
# 197    F
# 167    F
# 198    F
# 174    F
# 194    F
# 160    F
# 182    F
# 33     M
# 124    M
# 62     F
# 192    F
# 86     F
# 73     F
# 2      M
# 150    F
# 162    F
# 1      M
# 15     M
# 18     M
# 54     F
# 36     M
# 145    M
# 24     M
# 65     F
# 26     M
# 68     F
# 20     M
# 164    F
# 56     F
# 193    F
# 79     F
# 27     M
# Name: sex, dtype: object
# Độ chính xác của mô hình chưa Scale: 0.9333333333333333

# %%
model=Perceptron(max_iter=10000, eta0=0.05,random_state=0)
model.fit(x_train_Std,y_train)
y_pred = model.predict(x_test_Std)
print(y_pred)
print(y_test)
print("Độ chính xác của mô hình đã Scale:",accuracy_score(y_test,y_pred))
# Out:
# ['M' 'F' 'M' 'M' 'M' 'M' 'F' 'M' 'F' 'M' 'M' 'F' 'M' 'M' 'M' 'M' 'F' 'F'
#  'M' 'F' 'M' 'M' 'M' 'F' 'M' 'M' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'M'
#  'M' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'M' 'F' 'M' 'M' 'M' 'F' 'M' 'F'
#  'M' 'F' 'F' 'F' 'F' 'M']
# 179    F
# 57     F
# 7      M
# 133    M
# 46     M
# 37     M
# 196    F
# 137    M
# 171    F
# 34     M
# 101    M
# 53     F
# 132    M
# 8      M
# 115    M
# 125    M
# 180    F
# 64     F
# 5      M
# 155    F
# 103    M
# 117    M
# 149    M
# 87     F
# 31     M
# 144    M
# 69     F
# 129    M
# 197    F
# 167    F
# 198    F
# 174    F
# 194    F
# 160    F
# 182    F
# 33     M
# 124    M
# 62     F
# 192    F
# 86     F
# 73     F
# 2      M
# 150    F
# 162    F
# 1      M
# 15     M
# 18     M
# 54     F
# 36     M
# 145    M
# 24     M
# 65     F
# 26     M
# 68     F
# 20     M
# 164    F
# 56     F
# 193    F
# 79     F
# 27     M
# Name: sex, dtype: object
# Độ chính xác của mô hình đã Scale: 0.9333333333333333
